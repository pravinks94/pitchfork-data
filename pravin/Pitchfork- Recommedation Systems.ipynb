# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
import os
import sqlite3

# %%
os.chdir(r'../Data/')

# %%
conn=sqlite3.connect('./database.sqlite')

# %% [markdown]
# ### Artist Table

# %%
print(pd.read_sql_query('select * from artists',conn).head())
# print(pd.read_sql_query('select * from artists',conn).columns.values)
print(pd.read_sql_query('select * from artists',conn).columns)
# Out:
#    reviewid          artist
# 0     22703  massive attack
# 1     22721        krallice
# 2     22659    uranium club
# 3     22661         kleenex
# 4     22661         liliput
# Index(['reviewid', 'artist'], dtype='object')

# %% [markdown]
# ### Contents

# %%
print(pd.read_sql_query('select * from content',conn).head())
# Out:
#    reviewid                                            content
# 0     22703  “Trip-hop” eventually became a ’90s punchline,...
# 1     22721  Eight years, five albums, and two EPs in, the ...
# 2     22659  Minneapolis’ Uranium Club seem to revel in bei...
# 3     22661  Kleenex began with a crash. It transpired one ...
# 4     22725  It is impossible to consider a given release b...

# %%
pd.read_sql_query('select * from content',conn)['content'][1]
# Out:
# 'Eight years, five albums, and two EPs in, the New York-based outfit Krallice have long since shut up purists about their “hipster black metal.” Their four-man, post-structural assembly line runs at a breakneck pace, taking great care to balance the intricate (Colin Marston and Mick Barr’s interlocking riffs, Lev Weinstein’s head-spinning polyrhythms) with the incendiary (best exemplified by Barr and Nick McMaster’s shared, animalistic vocal duties; the former’s a screaming eagle, the latter a growling hellhound). The quartet frequently capitalize on the element of surprise; Krallice’s last two releases—2015’s Ygg Huur\xa0and last winter’s Hyperion\xa0EP—dropped spontaneously, a pair of inter-dimensional rifts masquerading as albums, far from the hum of the hype machine. Early last month, the band opened the portal once more to announce their sixth album Prelapsarian, subsequently released sans fanfare on the Winter Solstice. Upon first glance, Prelapsarian, which the band recorded last summer, may not seem like much. Comprising four tracks and thirty-five minutes, the LP stands just a smidge taller than its predecessor, and sports a similarly dense stylistic template. Fans familiar with the stop-go surges and antiphonal touches of old will undoubtedly appreciate “Transformation Chronicles,” “Conflagration”, and “Lotus Throne,” the album’s staggered, epic triad.Hyperion’s copious lyrical references to mythology, astrophysics, and nihilistic philosophy belied an obsession with the cosmic. Prelapsarian, by contrast, is the product of a band firmly planted on terra firma, racing against the doomsday clock. Post-election anxiety runs rampant, manifested in everything from the title (derived from the age of humanity’s primordial, Edenic innocence, the original “good old days” before Adam and Eve shared a snack and sealed humanity’s grim fate), to the razed-earth panoramas framing the doomy, eight-minute-long dirge “Conflagration.” “Hate Power,” is the the album’s highlight: an odd apex, considering it’s only the second track on the album, and clocking in at less than four minutes, the shortest. Krallice songs usually sprawl out across nine, eleven minutes; in these cramped confines, Barr and McMaster stage an epic battle for control as the band totters between d-beat and death metal. Without their usual song\xa0length as a cushion, the song feels like a fight to the death in a windowless room. As the song thrashes itself nearly apart, the doomsday-clock ticking desperation is palpable. In their growing catalog, this is a relatively crisp release, a speedy little roller coaster situated alongside the Towers of Terror. But the moment is dense and terrifying enough to make Krallice fans wonder: What could they accomplish with an album of compositions this compact?\xa0'

# %% [markdown]
# ### Genres

# %%
pd.read_sql_query('select * from genres',conn).head()
# Out:
#    reviewid       genre
# 0     22703  electronic
# 1     22721       metal
# 2     22659        rock
# 3     22661        rock
# 4     22725  electronic

# %% [markdown]
# ### Labels

# %%
pd.read_sql_query('select * from labels',conn).head()
# Out:
#    reviewid               label
# 0     22703              virgin
# 1     22721           hathenter
# 2     22659        static shock
# 3     22659  fashionable idiots
# 4     22661     kill rock stars

# %% [markdown]
# ### Reviews

# %%
reviews=pd.read_sql_query('select * from reviews',conn)
reviews.head()
# Out:
#    reviewid                 title            artist  \
# 0     22703             mezzanine    massive attack
# 1     22721          prelapsarian          krallice
# 2     22659  all of them naturals      uranium club
# 3     22661           first songs  kleenex, liliput
# 4     22725             new start              taso
#
#                                                  url  score  best_new_music  \
# 0  http://pitchfork.com/reviews/albums/22703-mezz...    9.3               0
# 1  http://pitchfork.com/reviews/albums/22721-prel...    7.9               0
# 2  http://pitchfork.com/reviews/albums/22659-all-...    7.3               0
# 3  http://pitchfork.com/reviews/albums/22661-firs...    9.0               1
# 4  http://pitchfork.com/reviews/albums/22725-new-...    8.1               0
#
#            author               author_type    pub_date  pub_weekday  pub_day  \
# 0     nate patrin               contributor  2017-01-08            6        8
# 1        zoe camp               contributor  2017-01-07            5        7
# 2  david glickman               contributor  2017-01-07            5        7
# 3      jenn pelly  associate reviews editor  2017-01-06            4        6
# 4    kevin lozano        tracks coordinator  2017-01-06            4        6
#
#    pub_month  pub_year
# 0          1      2017
# 1          1      2017
# 2          1      2017
# 3          1      2017
# 4          1      2017

# %%
reviews.title.value_counts()
# Out:
# dj-kicks                           20
# ii                                 17
# live                                9
# iii                                 8
# greatest hits                       7
#                                    ..
# rebellion hymns                     1
# rio grande blood                    1
# jackleg devotional to the heart     1
# walking with thee                   1
# flower with no color                1
# Name: title, Length: 17835, dtype: int64

# %%
reviews[reviews.title=='dj-kicks']
# Out:
#        reviewid     title                     artist  \
# 589       22105  dj-kicks                 jackmaster
# 738       21942  dj-kicks                    dm-funk
# 1117      21580  dj-kicks                  moodymann
# 1862      20677  dj-kicks                    dj koze
# 2928      19463  dj-kicks                  will saul
# 3669      18749  dj-kicks               john talabot
# 4965      17223  dj-kicks   hercules and love affair
# 5300      16824  dj-kicks                 digitalism
# 6095      15991  dj-kicks                 gold panda
# 6120      15928  dj-kicks                      scuba
# 6400      15684  dj-kicks   motor city drum ensemble
# 6870      15206  dj-kicks  wolf + lamb vs. soul clap
# 7282      14794  dj-kicks                    apparat
# 7686      14377  dj-kicks                      kode9
# 7796      14283  dj-kicks               james holden
# 7884      14165  dj-kicks           the juan maclean
# 8518      13561  dj-kicks                    chromeo
# 10577     11059  dj-kicks                booka shade
# 13251       457  dj-kicks                      annie
# 13891      3673  dj-kicks               the glimmers
#
#                                                      url  score  \
# 589    http://pitchfork.com/reviews/albums/22105-dj-k...    7.5
# 738    http://pitchfork.com/reviews/albums/21942-dj-k...    7.7
# 1117   http://pitchfork.com/reviews/albums/21580-dj-k...    8.4
# 1862   http://pitchfork.com/reviews/albums/20677-dj-k...    8.0
# 2928   http://pitchfork.com/reviews/albums/19463-will...    6.1
# 3669   http://pitchfork.com/reviews/albums/18749-john...    7.9
# 4965   http://pitchfork.com/reviews/albums/17223-dj-k...    7.0
# 5300   http://pitchfork.com/reviews/albums/16824-dj-k...    5.5
# 6095   http://pitchfork.com/reviews/albums/15991-gold...    7.5
# 6120   http://pitchfork.com/reviews/albums/15928-dj-k...    8.0
# 6400   http://pitchfork.com/reviews/albums/15684-dj-k...    8.0
# 6870   http://pitchfork.com/reviews/albums/15206-dj-k...    7.6
# 7282   http://pitchfork.com/reviews/albums/14794-dj-k...    7.2
# 7686   http://pitchfork.com/reviews/albums/14377-dj-k...    7.3
# 7796   http://pitchfork.com/reviews/albums/14283-dj-k...    7.7
# 7884   http://pitchfork.com/reviews/albums/14165-dj-k...    8.1
# 8518   http://pitchfork.com/reviews/albums/13561-dj-k...    6.5
# 10577  http://pitchfork.com/reviews/albums/11059-dj-k...    7.4
# 13251  http://pitchfork.com/reviews/albums/457-dj-kicks/    7.5
# 13891  http://pitchfork.com/reviews/albums/3673-dj-ki...    7.5
#
#        best_new_music             author       author_type    pub_date  \
# 589                 0       nathan reese       contributor  2016-07-15
# 738                 0       miles raymer       contributor  2016-06-03
# 1117                1          andy beta       contributor  2016-02-17
# 1862                0    mark richardson  executive editor  2015-06-16
# 2928                0  larry fitzmaurice       contributor  2014-07-09
# 3669                0  larry fitzmaurice       contributor  2013-11-15
# 4965                0         tim finney              None  2012-10-22
# 5300                0       jess harvell       contributor  2012-07-10
# 6095                0       jess harvell       contributor  2011-11-01
# 6120                0        andrew ryce       contributor  2011-10-25
# 6400                0       jess harvell       contributor  2011-07-29
# 6870                0          joe colly       contributor  2011-03-15
# 7282                0      tal rosenberg       contributor  2010-10-27
# 7686                0     andy battaglia              None  2010-06-24
# 7796                0          joe colly       contributor  2010-05-24
# 7884                0        nate patrin       contributor  2010-04-28
# 8518                0          mike orme              None  2009-10-09
# 10577               0         tim finney              None  2008-01-28
# 13251               0     nick sylvester       contributor  2005-10-25
# 13891               0     nick sylvester       contributor  2005-04-21
#
#        pub_weekday  pub_day  pub_month  pub_year
# 589              4       15          7      2016
# 738              4        3          6      2016
# 1117             2       17          2      2016
# 1862             1       16          6      2015
# 2928             2        9          7      2014
# 3669             4       15         11      2013
# 4965             0       22         10      2012
# 5300             1       10          7      2012
# 6095             1        1         11      2011
# 6120             1       25         10      2011
# 6400             4       29          7      2011
# 6870             1       15          3      2011
# 7282             2       27         10      2010
# 7686             3       24          6      2010
# 7796             0       24          5      2010
# 7884             2       28          4      2010
# 8518             4        9         10      2009
# 10577            0       28          1      2008
# 13251            1       25         10      2005
# 13891            3       21          4      2005
